# %%
import pandas as pd
import argparse as args
import numpy as np

# %% [markdown]
# # Migraine formatting:
#
# #### Reading the data:

# %%
migraine = pd.DataFrame(pd.read_csv("~/alzheimersproject/1_raw_data/migraine_hautakangas", 
                delim_whitespace=True, header=0, na_values='NA'))

migraine
# Out:
# /scratch/17086545/ipykernel_46351/3602989659.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   migraine = pd.DataFrame(pd.read_csv("~/alzheimersproject/1_raw_data/migraine_hautakangas",
#             rs_number chromosome     position reference_allele other_allele  \
# 0            1:592368          1     592368.0                G            A
# 1            1:636285          1     636285.0                C            T
# 2            1:637420          1     637420.0                T            C
# 3            1:649192          1     649192.0                T            A
# 4            1:657788          1     657788.0                G            C
# ...               ...        ...          ...              ...          ...
# 11380306  rs139273633          X  155229483.0                T            C
# 11380307  rs150057047          X  155229622.0                C            G
# 11380308  rs145421232          X  155229796.0                A            G
# 11380309  rs144749717          X  155230932.0                G            A
# 11380310  rs138096180          X  155233098.0                C            T
#
#                eaf      beta        se  beta_95L  beta_95U  ...  \
# 0         0.010199  0.136408  0.299302 -0.450224  0.723040  ...
# 1         0.096043  0.037062  0.027023 -0.015904  0.090028  ...
# 2         0.019151 -0.028000  0.195107 -0.410410  0.354410  ...
# 3         0.117561  0.032302  0.024450 -0.015621  0.080224  ...
# 4         0.219788 -0.009857  0.063584 -0.134481  0.114767  ...
# ...            ...       ...       ...       ...       ...  ...
# 11380306  0.346997 -0.052996  0.022289 -0.096684 -0.009309  ...
# 11380307  0.341794 -0.053095  0.022362 -0.096925 -0.009265  ...
# 11380308  0.341067 -0.053227  0.022415 -0.097161 -0.009293  ...
# 11380309  0.342003 -0.053848  0.022663 -0.098267 -0.009429  ...
# 11380310  0.352228 -0.053986  0.022706 -0.098490 -0.009482  ...
#
#           _-log10_p-value  q_statistic  q_p-value   i2  n_studies  n_samples  \
# 0                0.188031          0.0        1.0  1.0       5941       ??+?
# 1                0.769011          0.0        1.0  1.0     341050       +???
# 2                0.052632          0.0        1.0  1.0       5941       ??-?
# 3                0.729445          0.0        1.0  1.0     341050       +???
# 4                0.057108          0.0        1.0  1.0       5941       ??-?
# ...                   ...          ...        ...  ...        ...        ...
# 11380306         1.758328          0.0        1.0  1.0      40224       ???-
# 11380307         1.754406          0.0        1.0  1.0      40224       ???-
# 11380308         1.754750          0.0        1.0  1.0      40224       ???-
# 11380309         1.756437          0.0        1.0  1.0      40224       ???-
# 11380310         1.758243          0.0        1.0  1.0      40224       ???-
#
#           effects         Neff    rsid_ukbb marker
# 0            1106  rs561532399     1:592368    NaN
# 1           15773  rs545945172     1:636285    NaN
# 2            1398     1:637420     1:637420    NaN
# 3           16125  rs201942322     1:649192    NaN
# 4            1442     1:657788     1:657788    NaN
# ...           ...          ...          ...    ...
# 11380306     8883  rs139273633  X:155229483    NaN
# 11380307     8889  rs150057047  X:155229622    NaN
# 11380308     8856  rs145421232  X:155229796    NaN
# 11380309     8652  rs144749717  X:155230932    NaN
# 11380310     8501  rs138096180  X:155233098    NaN
#
# [11380311 rows x 22 columns]

# %%
# %%bash
#
# head -n 1 ~/alzheimersproject/1_raw_data/migraine_hautakangas
# Out:
# rs_number	chromosome	position	reference_allele	other_allele	eaf	beta	se	beta_95L	beta_95U	z	p.value	_-log10_p-value	q_statistic	q_p-value	i2	n_studies	n_samples	effects	Neff	rsid_ukbb	marker

# %% [markdown]
# From the table above, N is the only missing column. And then chromosome X is included, which needs to be deleted.

# %% [markdown]
# #### Adding an N column:

# %%
# %%bash
#
# awk -v OFS='\t' 'BEGIN { print "SNP", "CHR", "BP", "A1", "A2", "Z", "P", "N", "FREQ", "BETA", "SE"  } NR>2 { print $21, $2, $3, $4, $5, $11, $12, $13 = (873341), $6, $7, $8 }' ~/alzheimersproject/1_raw_data/migraine_hautakangas > migraine_all_cols

# %% [markdown]
# #### Removing potential non-rsIDs in the SNP column and removing chromosome X:

# %%
# %%bash
#
# awk -v OFS='\t' 'NR == 1 || $1 ~ "rs"' migraine_all_cols > migraine_onlyrs
# awk -v OFS='\t' 'NR == 1 || $2 != "X"' migraine_onlyrs > migraine_onlyrs_noX

# %% [markdown]
# #### Removing possible duplicates in the file:

# %%
# %%bash
#
# awk '!seen[$1]++' migraine_onlyrs_noX > migraine_formatted

# %% [markdown]
# #### Checking the file:

# %%
migraine = pd.DataFrame(pd.read_csv("~/alzheimersproject/2_formatting/migraine_formatted", 
                delim_whitespace=True, header=0, na_values='NA'))

migraine
# Out:
#                  SNP  CHR          BP A1 A2         Z         P       N  \
# 0         rs61769339    1    662622.0  A  G  1.185333  0.235865  873341
# 1         rs12238997    1    693731.0  G  A  0.458189  0.646838  873341
# 2         rs61769351    1    693823.0  C  G  1.233042  0.217539  873341
# 3         rs72631875    1    705882.0  A  G -1.640695  0.100859  873341
# 4         rs12029736    1    706368.0  A  G  0.159826  0.873000  873341
# ...              ...  ...         ... .. ..       ...       ...     ...
# 8749403    rs5771020   22  51232581.0  C  T  0.039936  0.968130  873341
# 8749404  rs200189535   22  51235959.0  C  T  0.997278  0.318616  873341
# 8749405  rs200507571   22  51236013.0  I  D -1.428243  0.153207  873341
# 8749406    rs3896457   22  51237063.0  C  T -0.238732  0.811307  873341
# 8749407  rs149733995   22  51238249.0  C  A -0.146292  0.883671  873341
#
#              FREQ      BETA        SE
# 0        0.111610  0.027319  0.023048
# 1        0.117222  0.009883  0.021570
# 2        0.113234  0.028201  0.022871
# 3        0.066553 -0.055090  0.033577
# 4        0.482703  0.002583  0.016164
# ...           ...       ...       ...
# 8749403  0.298334  0.000643  0.016092
# 8749404  0.194286  0.019893  0.019947
# 8749405  0.251078 -0.024537  0.017180
# 8749406  0.299954 -0.003727  0.015613
# 8749407  0.072902 -0.006451  0.044100
#
# [8749408 rows x 11 columns]

# %% [markdown]
# #### Checking for NaN, NA, inf:

# %%
# 1. Checking for NaN:
print(migraine.isnull().sum())

print('\n------------------------------\n')

# 2. Checking for NA:
print(migraine.isna().sum())
print('\n------------------------------\n')

# 3. Checking for inf:
print((migraine.isin([np.inf, -np.inf])).sum())
# Out:
# SNP     0
# CHR     0
# BP      0
# A1      0
# A2      0
# Z       0
# P       0
# N       0
# FREQ    0
# BETA    0
# SE      0
# dtype: int64
#
# ------------------------------
#
# SNP     0
# CHR     0
# BP      0
# A1      0
# A2      0
# Z       0
# P       0
# N       0
# FREQ    0
# BETA    0
# SE      0
# dtype: int64
#
# ------------------------------
#
# SNP     0
# CHR     0
# BP      0
# A1      0
# A2      0
# Z       0
# P       0
# N       0
# FREQ    0
# BETA    0
# SE      0
# dtype: int64

# %% [markdown]
# #### Checking P=0:

# %%
# %%bash
#
# # Checking for P=0:
# awk -v OFS='\t' 'NR == 1 || $7 == "0.0" || $7 == "0"' migraine_formatted | head
# Out:
# SNP	CHR	BP	A1	A2	Z	P	N	FREQ	BETA	SE
